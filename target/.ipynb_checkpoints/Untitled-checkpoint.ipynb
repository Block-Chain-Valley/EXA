# %%
import pandas as pd
import numpy as np
import requests
import json
import csv

# %%
df = pd.read_csv('./new_combined.csv')

# %%
df
# Out:
#        index chainId        dexId baseToken  \
# 0          0     bsc  pancakeswap      WBNB
# 1          1     bsc  pancakeswap      WBNB
# 2          2     bsc  pancakeswap      BONK
# 3          3     bsc  pancakeswap      FITM
# 4          4    heco         mdex       WHT
# ...      ...     ...          ...       ...
# 32869  33405  cronos       cougar       CGO
# 32870  33406  cronos   vvsfinance      DOGE
# 32871  33407  cronos   vvsfinance       V4S
# 32872  33408  cronos   cyborgswap       C18
# 32873  33409  cronos    mmfinance   XDSHARE
#
#                                  baseTokenAddress quoteToken  \
# 0      0xbb4CdB9CBd36B01bD1cBaEBF2De08d9173bc095c       USDT
# 1      0xbb4CdB9CBd36B01bD1cBaEBF2De08d9173bc095c       BUSD
# 2      0xDDDd7bd6059044367f179d1647a9f1Bf3D62b263       WBNB
# 3      0x41D52514F6eA0c90993AD36152072a144C12bDc7       WBNB
# 4      0x5545153CCFcA01fbd7Dd11C0b23ba694D9509A6F       USDT
# ...

# %%
df2= df[df['TRUE'] == '1']

# %%
df2.to_csv('./data.csv')

# %%
df3 = pd.read_csv('./')
