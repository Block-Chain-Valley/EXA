# %%
import pandas as pd
import numpy as np
import requests
import json
import csv

# %%
df = pd.read_csv('./filterWithLiquidityV2.csv')
df
# Out:
#       Unnamed: 0  Unnamed: 1  index    chainId        dexId baseToken  \
# 0              0           0      0        bsc  pancakeswap      WBNB
# 1              2           2      2        bsc  pancakeswap      BONK
# 2              3           3      3        bsc  pancakeswap      FITM
# 3              4           4      4       heco         mdex       WHT
# 4              5           5      5        bsc  pancakeswap        Pi
# ...          ...         ...    ...        ...          ...       ...
# 5263        6872       32800  33334  avalanche    traderjoe      MASS
# 5264        6877       32822  33357  avalanche    traderjoe      SNCT
# 5265        6878       32823  33358  avalanche     pangolin     SPORE
# 5266        6880       32839  33374  avalanche    traderjoe     SMRTr
# 5267        6881       32856  33391  avalanche    traderjoe    SWAP.e
#
#                                 baseTokenAddress quoteToken  \
# 0     0xbb4CdB9CBd36B01bD1cBaEBF2De08d9173bc095c       USDT
# 1     0xDDDd7bd6059044367f179d1647a9f1Bf3D62b263       WBNB
# 2     0x41D52514F6eA0c90993AD36152072a144C12bDc7       WBNB
# 3     0x5545153CCFcA01fbd7Dd11C0b23ba694D9509A6F       USDT
# 4     0xbB15c06Be1649F0e31078e9fF89d82674a681179       WBNB
# ...                                          ...        ...
# 5263  0x63Dd6F87e8BD5008878E51DaF473DFB3105C7537       USDC
# 5264  0x2905d6D6957983d9ED73BC019fF2782c39dd7a49      WAVAX
# 5265  0x6e7f5C0b9f4432716bDd0a77a3601291b9D9e985      WAVAX
# 5266  0x6D923f688C7FF287dc3A5943CAeefc994F97b290      WAVAX
# 5267  0xc7B5D72C836e718cDA8888eaf03707fAef675079      WAVAX
#
#                                quoteTokenAddress  \
# 0     0x55d398326f99059fF775485246999027B3197955
# 1     0xbb4CdB9CBd36B01bD1cBaEBF2De08d9173bc095c
# 2     0xbb4CdB9CBd36B01bD1cBaEBF2De08d9173bc095c
# 3     0xa71EdC38d189767582C38A3145b5873052c3e47a
# 4     0xbb4CdB9CBd36B01bD1cBaEBF2De08d9173bc095c
# ...                                          ...
# 5263  0xB97EF9Ef8734C71904D8002F8b6Bc66Dd9c48a6E
# 5264  0xB31f66AA3C1e785363F0875A1B74E27b85FD66c7
# 5265  0xB31f66AA3C1e785363F0875A1B74E27b85FD66c7
# 5266  0xB31f66AA3C1e785363F0875A1B74E27b85FD66c7
# 5267  0xB31f66AA3C1e785363F0875A1B74E27b85FD66c7
#
#                                      pairAddress  \
# 0     0x16b9a82891338f9bA80E2D6970FddA79D1eb0daE
# 1     0xe30339DA40c0269C3a9828c6a3CE1f7d42477ccA
# 2     0xdD123e5749BB13012aF48b4BcF891146c4f84c45
# 3     0x499B6E03749B4bAF95F9E70EeD5355b138EA6C31
# 4     0x76EDCcd103CBfffceF43902e93c61823026fbc66
# ...                                          ...
# 5263  0x0B26B022Feb7B3823140C87598c5472cA49dc8A1
# 5264  0xd81425a1E9A09015B965243F803EF30b6AA605C3
# 5265  0x0a63179a8838b5729E79D239940d7e29e40A0116
# 5266  0x7B7617c7B2236D7871741783caE8BCc222C2e05D
# 5267  0xbd640457A0A2DE67fE18D9ad6756Dd2d501F08B6
#
#                                               liquidity  TRUE
# 0     {"usd":121690188.89270122,"base":237541,"quote...     1
# 1     {"usd":193212.94408014332,"base":2555408431625...     1
# 2     {"usd":132301.72410937824,"base":25907532,"quo...     1
# 3     {"usd":1410403.56057628,"base":155952,"quote":...     1
# 4     {"usd":189635.09368355313,"base":397718118,"qu...     1
# ...                                                 ...   ...
# 5263           {"usd":62585,"base":57828,"quote":31293}     1
# 5264         {"usd":67142,"base":16992072,"quote":2914}     1
# 5265  {"usd":54386,"base":2019851948240721,"quote":2...     1
# 5266   {"usd":149929,"base":1197219706674,"quote":6419}     1
# 5267           {"usd":51675,"base":152627,"quote":2176}     1
#
# [5268 rows x 12 columns]

# %%
df2 = pd.read_csv('./BinanceThicker.csv')
df2
# Out:
#      Binance thicker
# 0                ETH
# 1                LTC
# 2                BNB
# 3                NEO
# 4               QTUM
# ...              ...
# 2318             OGN
# 2319             AXS
# 2320            AVAX
# 2321            TOMO
# 2322             BCH
#
# [2323 rows x 1 columns]

# %%
overlap = []
for thicker in df2['Binance thicker']:
    for token in df['baseToken']:
        if thicker in token:
            overlap.append(token)
overlap
# Out:
# ['WETH',
#  'WETH',
#  'WETH',
#  'ETH',
#  'ETH',
#  'WETH',
#  'ETH',
#  'vETH',
#  'ETH',
#  'WETH',
#  'WETH',
#  'ETH2x-FLI',
#  'sETH2',
#  'wstETH',
#  'WETH',
#  'WETH',
#  'ETHERNAL',
#  'WETH',
#  'ankrETH',
#  'WETH',
#  'WETH',
#  'WETH',
#  'ETHIX',
#  'ibETHv2',
#  'ETH',
#  'wstETH',
#  'ETH',
#  'ETH',
#  'WETH.e',
#  'WETH.e',
#  'ETH',
#  'WETH',
#  'WETH',
#  'WETH',
#  'WETH',
#  'WETH',
#  'ETH',
#  'WETH',
#  'lqETH',
#  'ETH',
#  'WETH',
#  'rETH',
#  'ETH',
#  'WETH',
#  'ETH',
#  'alETH',
#  'dynETH',
#  'stETH',
#  'WETH',
#  'cbETH',
#  'ETH',
#  'ETHMAXY',
#  'ETH',
#  'WETH',
#  'rETH',
#  'WETH',
#  'ETH',
#  '$ETHSHIB',
#  'WETH',
#  'ETH',
#  'WETH',
#  'WETH',
#  'ETH',
#  'WETH',
#  'WETH',
#  'maWETH',
#  'ETHA',
#  'WETH',
#  'wanETH',
#  'ETH',
#  'ETH',
#  'axlWETH',
#  'wstETH',
#  'ETH',
#  'ETH',
#  'WETH',
#  'WETH',
#  'WETH',
#  'ETH',
#  'bbETH',
#  'WETH',
#  'WETH',
#  'rETH2',
#  'WETH',
#  'ETH',
#  'ETHi',
#  'wstETH',
#  'ceWETH',
#  'ETH',
#  'sETH',
#  'ETH',
#  'WETH',
#  'ETH',
#  'WETH',
#  'WETH',
#  'TETHYS',
#  'ETH',
#  'WETH',
#  'ETH',
#  'WETH',
#  'oETH',
#  'ioETH',
#  'WETH',
#  'WETH',
#  'ETH',
#  'EverETH',
#  'WETH',
#  'oETH',
#  'ETH',
#  'WETH',
#  'WETH.grv',
#  'WETH',
#  'ETH',
#  'WETH',
#  'ETHK',
#  'ETH',
#  'wstETH',
#  'WETH',
#  'WETH',
#  'cxETH',
#  'WETH',
#  'ETH',
#  'ETH',
#  'WETH',
#  'WETH',
#  'wstETH',
#  'WETH.e',
#  'WETH',
#  'WETH',
#  'ETH2x-FLI-P',
#  'ETH',
#  'wstETH',
#  'WETH',
#  'WETH',
#  'ETH',
#  'alETH',
#  'WETH',
#  'WETH',
#  'iETHV',
#  'WETH',
#  'ETH',
#  'WETH',
#  'ETH',
#  'ETH',
#  'ETHS',
#  'ETHV',
#  'wstETH',
#  'WETH',
#  'WETH',
#  'ETH',
#  'ETH',
#  'ETH',
#  'ETH',
#  'icETH',
#  'ETH',
#  'WETH',
#  'ETHPAD',
#  'jETH',
#  'WETH',
#  'ETH',
#  'LTC',
#  'LTC',
#  'LTCK',
#  'LTC',
#  'LTC',
#  'HLTC',
#  'LTC',
#  'WBNB',
#  'WBNB',
#  'WBNB',
#  'DBNB',
#  'WBNB',
#  'WBNB',
#  'WBNB',
#  'WBNB',
#  'WBNB',
#  'WBNB',
#  'WBNB',
#  'WBNB',
#  'WBNB',
#  'BNBP',
#  'WBNB',
#  'BNBi',
#  'BNB',
#  'WBNB',
#  'SBNB',
#  'BNBD',
#  'stkBNB',
#  'WBNB',
#  'BNB',
#  'BNB',
#  'WBNB',
#  'WBNB',
#  'BNB',
#  'WBNB',
#  'WBNB',
#  'WBNB',
#  'WBNB',
#  'BNB',
#  'WBNB',
#  'WBNB',
#  'WBNB',
#  'WBNB',
#  'WBNB',
#  'WBNB',
#  'WBNB',
#  'WBNB',
#  'BNB',
#  'BNBx',
#  'WBNB',
#  'BNB',
#  'WBNB',
#  'WBNB',
#  'BNB|bsc',
#  'BNBx',
#  'WBNB',
#  'WBNB',
#  'BNB-MP',
#  'BNB',
#  'WBNB',
#  'BNB',
#  'BNB',
#  'vBNB',
#  'NBU_WBNB',
#  'BNB',
#  'BNB',
#  'iBNB',
#  'WBNB',
#  'WBNB',
#  'EOS',
#  'EOS',
#  'SNT',
#  'SNTVT',
#  'BNT',
#  'BCC',
#  'GAS',
#  'VEGAS',
#  'WBTC',
#  'vBTC',
#  'BTCB',
#  'BTC',
#  'WBTC',
#  'BTC.b',
#  'BTCK',
#  'BTCB',
#  'WBTC',
#  'BTC.b',
#  'BTC-MP',
#  'oWBTC',
#  'WBTC',
#  'WBTC',
#  'pBTC',
#  'BTC',
#  'WBTC',
#  'BTC.m',
#  'WBTC',
#  'renBTC',
#  'pBTC35A',
#  'pBTC',
#  'oBTC',
#  'WBTC',
#  'BTC',
#  'oneBTC',
#  'renBTC',
#  'BTCB',
#  'BTCK',
#  'BTCB',
#  'BTCPi',
#  'wanBTC',
#  'WBTC',
#  'xcIBTC',
#  'WBTC',
#  'WBTC',
#  'WBTC',
#  'BTCMT',
#  'BTCB',
#  'WBTC',
#  'BTCK',
#  'WBTC',
#  'bbBTC',
#  'BTC',
#  'WBTC',
#  'WBTC',
#  '0xBTC',
#  'BTCB',
#  'WBTC.e',
#  'WBTC',
#  'BTC',
#  'WBTC',
#  'BTCB',
#  'WBTC',
#  'BTC',
#  'BTCB|bsc',
#  'WBTC',
#  'BTC',
#  'WBTC|eth',
#  'WBTC',
#  'HBTC',
#  'WBTC',
#  'WBTC',
#  'BTCB',
#  'BTC.b',
#  'm.WBTC',
#  'BTCB',
#  'BTCB',
#  'BTCB',
#  'WBTC',
#  'axlWBTC',
#  'BBTC',
#  'WBTC',
#  'WBTC',
#  'WBTC',
#  'xcIBTC',
#  'ioWBTC',
#  'WBTC',
#  'WBTC',
#  'WBTC',
#  'WBTC.e',
#  'WBTC',
#  'BTC',
#  'WBTC',
#  'BTCB',
#  'WBTC',
#  'WBTC',
#  'bitBTC',
#  'BTCF',
#  'BTC-MP',
#  'WBTC.e',
#  'WBTC',
#  'BTCB',
#  'BTCnow',
#  'BTC',
#  'WBTC',
#  'WBTC',
#  'WBTC',
#  'BTCC',
#  'NEBTC',
#  'BTCK',
#  'BTCDOG',
#  'BTCB',
#  'WBTC',
#  'WBTC',
#  'WBTC',
#  'WBTC',
#  'WBTC',
#  'BTCST',
#  'WETH',
#  'WETH',
#  'WETH',
#  'ETH',
#  'ETH',
#  'WETH',
#  'ETH',
#  'vETH',
#  'ETH',
#  'WETH',
#  'WETH',
#  'ETH2x-FLI',
#  'sETH2',
#  'wstETH',
#  'WETH',
#  'WETH',
#  'ETHERNAL',
#  'WETH',
#  'ankrETH',
#  'WETH',
#  'WETH',
#  'WETH',
#  'ETHIX',
#  'ibETHv2',
#  'ETH',
#  'wstETH',
#  'ETH',
#  'ETH',
#  'WETH.e',
#  'WETH.e',
#  'ETH',
#  'WETH',
#  'WETH',
#  'WETH',
#  'WETH',
#  'WETH',
#  'ETH',
#  'WETH',
#  'lqETH',
#  'ETH',
#  'WETH',
#  'rETH',
#  'ETH',
#  'WETH',
#  'ETH',
#  'alETH',
#  'dynETH',
#  'stETH',
#  'WETH',
#  'cbETH',
#  'ETH',
#  'ETHMAXY',
#  'ETH',
#  'WETH',
#  'rETH',
#  'WETH',
#  'ETH',
#  '$ETHSHIB',
#  'WETH',
#  'ETH',
#  'WETH',
#  'WETH',
#  'ETH',
#  'WETH',
#  'WETH',
#  'maWETH',
#  'ETHA',
#  'WETH',
#  'wanETH',
#  'ETH',
#  'ETH',
#  'axlWETH',
#  'wstETH',
#  'ETH',
#  'ETH',
#  'WETH',
#  'WETH',
#  'WETH',
#  'ETH',
#  'bbETH',
#  'WETH',
#  'WETH',
#  'rETH2',
#  'WETH',
#  'ETH',
#  'ETHi',
#  'wstETH',
#  'ceWETH',
#  'ETH',
#  'sETH',
#  'ETH',
#  'WETH',
#  'ETH',
#  'WETH',
#  'WETH',
#  'TETHYS',
#  'ETH',
#  'WETH',
#  'ETH',
#  'WETH',
#  'oETH',
#  'ioETH',
#  'WETH',
#  'WETH',
#  'ETH',
#  'EverETH',
#  'WETH',
#  'oETH',
#  'ETH',
#  'WETH',
#  'WETH.grv',
#  'WETH',
#  'ETH',
#  'WETH',
#  'ETHK',
#  'ETH',
#  'wstETH',
#  'WETH',
#  'WETH',
#  'cxETH',
#  'WETH',
#  'ETH',
#  'ETH',
#  'WETH',
#  'WETH',
#  'wstETH',
#  'WETH.e',
#  'WETH',
#  'WETH',
#  'ETH2x-FLI-P',
#  'ETH',
#  'wstETH',
#  'WETH',
#  'WETH',
#  'ETH',
#  'alETH',
#  'WETH',
#  'WETH',
#  'iETHV',
#  'WETH',
#  'ETH',
#  'WETH',
#  'ETH',
#  'ETH',
#  'ETHS',
#  'ETHV',
#  'wstETH',
#  'WETH',
#  'WETH',
#  'ETH',
#  'ETH',
#  'ETH',
#  'ETH',
#  'icETH',
#  'ETH',
#  'WETH',
#  'ETHPAD',
#  'jETH',
#  'WETH',
#  'ETH',
#  'RDNT',
#  'MCOIN',
#  'MCONTENT',
#  'ICNV2',
#  'LRC',
#  'ZRX',
#  'KNC',
#  'KNC',
#  'KNC',
#  'KNC',
#  'FUND',
#  'FUN',
#  'SFUND',
#  'xFUND',
#  'xFUND',
#  'SFUND',
#  'SFUND',
#  'SNM',
#  'IOTA',
#  'LINK',
#  'LINK',
#  'LINK',
#  'LINK',
#  'LINK',
#  'LINK',
#  'LINK',
#  'LINK',
#  'LINK',
#  'LINK',
#  'LINK.e',
#  'LINK',
#  'LINK',
#  'LINK',
#  'vLINK',
#  'LINK.e',
#  'LINK',
#  'LINKS',
#  'LINK',
#  'LINK.e',
#  'LINK',
#  'LINK',
#  'LINK',
#  'LINK',
#  'SALT',
#  'MDAO',
#  'MTLX',
#  'NETC',
#  'FETCH',
#  'ETC',
#  'ETC',
#  'renZEC',
#  'ZEC',
#  'nASTR',
#  'ASTRAFER',
#  'ASTRA',
#  'BLAST',
#  'ASTRAFER',
#  'WASTR',
#  'ASTRAFER',
#  'ASTO',
#  'ASTRAFER',
#  'KASTA',
#  'WASTR',
#  'FAST',
#  'ASTRO',
#  'ASTRO',
#  'AST',
#  'REQ',
#  'REQ',
#  'REQ',
#  'TRX',
#  'TRX',
#  'TRX',
#  'STRX',
#  'TRX',
#  'MTRX',
#  'POWR',
#  'ARK',
#  'SHARK',
#  'ARKM',
#  'ARKFI',
#  'DARK',
#  'ARKER',
#  'DARK',
#  'DARK',
#  'SPARK',
#  'XRP',
#  'wanXRP',
#  'BBYXRP',
#  'XRP',
#  'XRPC',
#  'XRP',
#  'XRP',
#  'XRP',
#  'XRP',
#  'MODA',
#  'ENJ',
#  'STORJ',
#  'VENO',
#  '$HAVEN',
#  'VENT',
#  'SEVEN',
#  'RDNT',
#  'AMB',
#  'BAT',
#  'WOMBAT',
#  'BAT',
#  'IBAT',
#  'BATH',
#  'BAT',
#  '$EARN',
#  'EARN',
#  'BGVT',
#  'BCDT',
#  'CDT',
#  'QSP',
#  'BTSE',
#  'BTSG',
#  'BTSCRW',
#  'HFUEL',
#  'MANA',
#  'MANA',
#  'MANA',
#  'MANA',
#  'MANA',
#  'MANA',
#  'BCDT',
#  'ADX',
#  'ADXX',
#  'ADX',
#  'ADA',
#  'ADA',
#  'ZADA',
#  'RADAR',
#  'RADAR',
#  'ADA',
#  'ADA',
#  'RIADA',
#  'ADA',
#  'ADA',
#  'ADAcash',
#  'RADAR',
#  'METADAO2.0',
#  'ADAPAD',
#  'ADA',
#  'LUNADAO',
#  'RADAR',
#  'ADA',
#  'BTCMT',
#  'XLM',
#  'LENDA',
#  'TNB',
#  'BOOST',
#  'ELFI',
#  'ELFI',
#  'SELF',
#  'ELF',
#  'ELF',
#  'LBRD',
#  'BRDG',
#  'WIFEDOGE',
#  'EDOGE',
#  'SHUNAV2',
#  'WNAV',
#  'LUNC',
#  'LUNA',
#  'LUNA',
#  'LUNI',
#  'LUNG',
#  'LUNADAO',
#  'LUNG',
#  'RLC',
#  'RLC',
#  'GAINS',
#  'INSUR',
#  '$MAINST',
#  'COINSCOPE',
#  'GAINS',
#  'INSUR',
#  'INSURE',
#  'TRIVIA',
#  'TRIVIA',
#  'BLZ',
#  'AESTRAL',
#  'RAE',
#  'AERA',
#  'YAE',
#  'AEC',
#  'AELIN',
#  'SAFEMOONCASH',
#  'ZIL',
#  'ZIL',
#  'DOGEZILLA',
#  'ELONTC',
#  'MOONTOKEN',
#  'ONT',
#  'MCONTENT',
#  'ONT',
#  'WWAN',
#  'WANA',
#  'SWPR',
#  'PSYS',
#  'WSYS',
#  'CLOAK',
#  'LOOM',
#  'BCNA',
#  'DREP',
#  'REPv2',
#  'TUSD',
#  'TUSD',
#  'TUSD',
#  'TUSD',
#  'TUSD',
#  'TUSD',
#  'TUSD',
#  'TUSD',
#  'BZEN',
#  'PZEN',
#  'ZENIQ',
#  'SKY',
#  'SKY',
#  'SKY',
#  'IOTX',
#  'WIOTX',
#  'IOTX',
#  'CIOTX',
#  'CIOTX',
#  'IOTX',
#  'QKC',
#  'MAGIC',
#  'MAGIC',
#  'AGIX',
#  'MAGIC',
#  'MAGIC2',
#  'MAGIC',
#  'MAGIC',
#  'DATA',
#  'DATA',
#  'DATA',
#  'DATA',
#  'KSC',
#  'BSC-HO',
#  'RISC',
#  'ESC',
#  'BSCAnt3',
#  'MSC',
#  'SCRL',
#  'SHIBSC',
#  'DSC',
#  'MNTTBSC',
#  'COINSCOPE',
#  'SCRT',
#  'GSC',
#  'BSC-HO',
#  'SCLP',
#  'BSCPAD',
#  'SCT',
#  'BTSCRW',
#  'BSCS',
#  'SCAR',
#  'BSCS',
#  'ASCO',
#  'SCORCH',
#  'BSC-ZEED',
#  'SCAR',
#  'MBSC',
#  'MSC',
#  'ESC',
#  'SCREAM',
#  'SCAN',
#  'MSCP',
#  'MSC',
#  'BSC-EPK',
#  'SCROOGE JR',
#  'SC',
#  'SCK',
#  'WSCRT',
#  'BSCX',
#  'CSC',
#  'OSC',
#  'DSCPL',
#  'BSCV',
#  'MSC',
#  'KEY',
#  'KEYS',
#  'NASA',
#  'NASSR',
#  'DENT',
#  'HOT',
#  'HOT',
#  'HOTCROSS',
#  'VET',
#  'VET',
#  'VETTER',
#  'POLYPAD',
#  'POLYPAD',
#  'PHX',
#  'CHC',
#  'VHC',
#  'CHC',
#  'THC',
#  'IHC',
#  'IHC',
#  'GHC',
#  'MCHC',
#  'BHC',
#  'MCHC',
#  'TANGO',
#  'GOVI',
#  'WIGO',
#  'KGO',
#  'GOGE',
#  'GOTG',
#  'GOKU',
#  'MONGOOSE',
#  'AIGO',
#  'GOG',
#  'ALGOBLK',
#  'VGO',
#  'PGOSK',
#  'GODZ',
#  'MSGO',
#  'GOVI',
#  'EGOLD',
#  'GOVI',
#  'ARGO',
#  'LEGO',
#  'GOD',
#  'GOVI',
#  'AGOV',
#  'GODS',
#  'FROGGO',
#  'DRAGON',
#  'MGOD',
#  'DGOD',
#  'YESGO',
#  'RGOLD',
#  '$GOD',
#  'PAXG',
#  'USDC',
#  'USDC',
#  'USDC',
#  'USDCi',
#  'USDC',
#  'USDC.e',
#  'USDC-HECO',
#  'USDC.e',
#  'USDC',
#  'USDC',
#  'USDC',
#  'USDC',
#  'USDC',
#  'USDC',
#  'USDC.e',
#  'USDC',
#  'USDC',
#  'USDC',
#  'USDC',
#  'USDC',
#  'USDC',
#  'USDC',
#  'USDC',
#  'USDC',
#  'USDC',
#  'USDC',
#  'USDC',
#  'oUSDC',
#  'USDC',
#  'USDC',
#  'USDC',
#  'USDC',
#  'USDC',
#  'USDC',
#  'USDC.e',
#  'USDC',
#  'USDC',
#  'USDC',
#  'USDC',
#  'axlUSDC',
#  'USDC',
#  'USDC',
#  'USDC',
#  'USDC',
#  'USDC',
#  'USDC',
#  'USDC',
#  'USDC',
#  'USDC',
#  'USDC',
#  'USDC',
#  'USDC',
#  'USDC',
#  'USDC',
#  'USDC.grv',
#  'ceUSDC',
#  'USDC',
#  'USDC',
#  'USDC',
#  'USDC',
#  'USDC',
#  'oUSDC',
#  'sUSDC',
#  'USDC',
#  'USDC',
#  'indexUSDC',
#  'USDC',
#  'USDC',
#  'BCH',
#  'BCH',
#  'bcBCH',
#  'RENA',
#  'REN',
#  'REN',
#  'FREN',
#  'BTT',
#  'BTT',
#  'BTT',
#  'USDS',
#  'MONGOOSE',
#  'STRONG',
#  'MKONG',
#  'MFET',
#  'FETCH',
#  'FET',
#  'CELR',
#  'WMATIC',
#  'WMATIC',
#  'miMATIC',
#  'MATIC',
#  'MATIC',
#  'MATIC',
#  'MATIC',
#  'stMATIC',
#  'WMATIC',
#  'MATIC',
#  'WMATIC',
#  'WMATIC',
#  'WMATIC',
#  'vMATIC',
#  'MATIC',
#  'WMATIC',
#  'WMATIC',
#  'stMATIC',
#  'stMATIC',
#  'AXMATIC',
#  'WMATIC',
#  'stMATIC',
#  'MATIC',
#  'MATIC',
#  'WMATIC',
#  'WMATIC',
#  'WMATIC',
#  'stMATIC',
#  'MATIC',
#  'MATIC',
#  'WMATIC',
#  'MATIC',
#  'MATICPAD',
#  'miMATIC',
#  'WMATIC',
#  'ATOM',
#  'stATOM',
#  'ATOM',
#  'ATOM',
#  'ATOM',
#  'ATOM',
#  'vATOM',
#  'ATOM',
#  'stkATOM',
#  'BONE',
#  'BONE',
#  'MONES',
#  'ZONE',
#  'JONES',
#  '$HONEY',
#  'WONE',
#  'ONE',
#  'GZONE',
#  'WONE',
#  'ONE',
#  'ONE',
#  'MOONEY',
#  'JONES',
#  'ELONONE',
#  'GZONE',
#  'WFTM',
#  'WFTM',
#  'vFTM',
#  'WFTM',
#  'WFTM',
#  'WFTM',
#  'FTM',
#  'WFTM',
#  'beFTM',
#  ...]

# %%
remove = []
for i in range(len(df['baseToken'])):
    if df['baseToken'][i] not in overlap:
        remove.append(i)
remove.reverse()    
for r in remove:
        df.drop(df.index[r],inplace =True)

# %%
df
# Out:
#       Unnamed: 0  Unnamed: 1  index    chainId        dexId baseToken  \
# 0              0           0      0        bsc  pancakeswap      WBNB
# 2              3           3      3        bsc  pancakeswap      FITM
# 3              4           4      4       heco         mdex       WHT
# 5              6           6      6   arbitrum      uniswap      WETH
# 6              7           7      7    polygon      uniswap    WMATIC
# ...          ...         ...    ...        ...          ...       ...
# 5258        6861       32706  33237    polygon      uniswap       XMT
# 5259        6865       32759  33292   arbitrum      camelot      OATH
# 5262        6871       32792  33325   optimism      uniswap      AAVE
# 5264        6877       32822  33357  avalanche    traderjoe      SNCT
# 5266        6880       32839  33374  avalanche    traderjoe     SMRTr
#
#                                 baseTokenAddress quoteToken  \
# 0     0xbb4CdB9CBd36B01bD1cBaEBF2De08d9173bc095c       USDT
# 2     0x41D52514F6eA0c90993AD36152072a144C12bDc7       WBNB
# 3     0x5545153CCFcA01fbd7Dd11C0b23ba694D9509A6F       USDT
# 5     0x82aF49447D8a07e3bd95BD0d56f35241523fBab1       USDC
# 6     0x0d500B1d8E8eF31E21C99d1Db9A6444d3ADf1270       USDC
# ...                                          ...        ...
# 5258  0xadBe0eac80F955363f4Ff47B0f70189093908c04       USDC
# 5259  0xa1150db5105987CEC5Fd092273d1e3cbb22b378b       WETH
# 5262  0x76FB31fb4af56892A25e32cFC43De717950c9278        ETH
# 5264  0x2905d6D6957983d9ED73BC019fF2782c39dd7a49      WAVAX
# 5266  0x6D923f688C7FF287dc3A5943CAeefc994F97b290      WAVAX
#
#                                quoteTokenAddress  \
# 0     0x55d398326f99059fF775485246999027B3197955
# 2     0xbb4CdB9CBd36B01bD1cBaEBF2De08d9173bc095c
# 3     0xa71EdC38d189767582C38A3145b5873052c3e47a
# 5     0xFF970A61A04b1cA14834A43f5dE4533eBDDB5CC8
# 6     0x2791Bca1f2de4661ED88A30C99A7a9449Aa84174
# ...                                          ...
# 5258  0x2791Bca1f2de4661ED88A30C99A7a9449Aa84174
# 5259  0x82aF49447D8a07e3bd95BD0d56f35241523fBab1
# 5262  0x4200000000000000000000000000000000000006
# 5264  0xB31f66AA3C1e785363F0875A1B74E27b85FD66c7
# 5266  0xB31f66AA3C1e785363F0875A1B74E27b85FD66c7
#
#                                      pairAddress  \
# 0     0x16b9a82891338f9bA80E2D6970FddA79D1eb0daE
# 2     0xdD123e5749BB13012aF48b4BcF891146c4f84c45
# 3     0x499B6E03749B4bAF95F9E70EeD5355b138EA6C31
# 5     0xC31E54c7a869B9FcBEcc14363CF510d1c41fa443
# 6     0xA374094527e1673A86dE625aa59517c5dE346d32
# ...                                          ...
# 5258  0xf7aBB7dee889dA4300a82C26f8c0c725c64Bd493
# 5259  0x7fFAf4698635a7679CE508160f2156B8739f37fE
# 5262  0x790fde1FD6d2568050061a88c375d5c2E06b140B
# 5264  0xd81425a1E9A09015B965243F803EF30b6AA605C3
# 5266  0x7B7617c7B2236D7871741783caE8BCc222C2e05D
#
#                                               liquidity  TRUE
# 0     {"usd":121690188.89270122,"base":237541,"quote...     1
# 2     {"usd":132301.72410937824,"base":25907532,"quo...     1
# 3     {"usd":1410403.56057628,"base":155952,"quote":...     1
# 5       {"usd":15980362,"base":6858.66,"quote":7432377}     1
# 6        {"usd":7037957,"base":7028722,"quote":1579534}     1
# ...                                                 ...   ...
# 5258     {"usd":461022,"base":29180285,"quote":7997.94}     1
# 5259  {"usd":526986.0214139478,"base":3112908,"quote...     1
# 5262        {"usd":129404,"base":1935.23,"quote":17.73}     1
# 5264         {"usd":67142,"base":16992072,"quote":2914}     1
# 5266   {"usd":149929,"base":1197219706674,"quote":6419}     1
#
# [2671 rows x 12 columns]

# %%
df.drop(['Unnamed: 0','Unnamed: 1','index'],axis ='columns')
drop_pairAddress = ["0xf20d962a6c8f70c731bd838a3a388D7d48fA6e15"]
for i in range(len(df['baseToken'])):
    if df.drop['pairAddress'][i] not in overlap:
        remove.append(i)
# Out:
#       Unnamed: 0  Unnamed: 1  index    chainId        dexId baseToken  \
# 0              0           0      0        bsc  pancakeswap      WBNB
# 2              3           3      3        bsc  pancakeswap      FITM
# 3              4           4      4       heco         mdex       WHT
# 5              6           6      6   arbitrum      uniswap      WETH
# 6              7           7      7    polygon      uniswap    WMATIC
# ...          ...         ...    ...        ...          ...       ...
# 5258        6861       32706  33237    polygon      uniswap       XMT
# 5259        6865       32759  33292   arbitrum      camelot      OATH
# 5262        6871       32792  33325   optimism      uniswap      AAVE
# 5264        6877       32822  33357  avalanche    traderjoe      SNCT
# 5266        6880       32839  33374  avalanche    traderjoe     SMRTr
#
#                                 baseTokenAddress quoteToken  \
# 0     0xbb4CdB9CBd36B01bD1cBaEBF2De08d9173bc095c       USDT
# 2     0x41D52514F6eA0c90993AD36152072a144C12bDc7       WBNB
# 3     0x5545153CCFcA01fbd7Dd11C0b23ba694D9509A6F       USDT
# 5     0x82aF49447D8a07e3bd95BD0d56f35241523fBab1       USDC
# 6     0x0d500B1d8E8eF31E21C99d1Db9A6444d3ADf1270       USDC
# ...                                          ...        ...
# 5258  0xadBe0eac80F955363f4Ff47B0f70189093908c04       USDC
# 5259  0xa1150db5105987CEC5Fd092273d1e3cbb22b378b       WETH
# 5262  0x76FB31fb4af56892A25e32cFC43De717950c9278        ETH
# 5264  0x2905d6D6957983d9ED73BC019fF2782c39dd7a49      WAVAX
# 5266  0x6D923f688C7FF287dc3A5943CAeefc994F97b290      WAVAX
#
#                                quoteTokenAddress  \
# 0     0x55d398326f99059fF775485246999027B3197955
# 2     0xbb4CdB9CBd36B01bD1cBaEBF2De08d9173bc095c
# 3     0xa71EdC38d189767582C38A3145b5873052c3e47a
# 5     0xFF970A61A04b1cA14834A43f5dE4533eBDDB5CC8
# 6     0x2791Bca1f2de4661ED88A30C99A7a9449Aa84174
# ...                                          ...
# 5258  0x2791Bca1f2de4661ED88A30C99A7a9449Aa84174
# 5259  0x82aF49447D8a07e3bd95BD0d56f35241523fBab1
# 5262  0x4200000000000000000000000000000000000006
# 5264  0xB31f66AA3C1e785363F0875A1B74E27b85FD66c7
# 5266  0xB31f66AA3C1e785363F0875A1B74E27b85FD66c7
#
#                                      pairAddress  \
# 0     0x16b9a82891338f9bA80E2D6970FddA79D1eb0daE
# 2     0xdD123e5749BB13012aF48b4BcF891146c4f84c45
# 3     0x499B6E03749B4bAF95F9E70EeD5355b138EA6C31
# 5     0xC31E54c7a869B9FcBEcc14363CF510d1c41fa443
# 6     0xA374094527e1673A86dE625aa59517c5dE346d32
# ...                                          ...
# 5258  0xf7aBB7dee889dA4300a82C26f8c0c725c64Bd493
# 5259  0x7fFAf4698635a7679CE508160f2156B8739f37fE
# 5262  0x790fde1FD6d2568050061a88c375d5c2E06b140B
# 5264  0xd81425a1E9A09015B965243F803EF30b6AA605C3
# 5266  0x7B7617c7B2236D7871741783caE8BCc222C2e05D
#
#                                               liquidity  TRUE
# 0     {"usd":121690188.89270122,"base":237541,"quote...     1
# 2     {"usd":132301.72410937824,"base":25907532,"quo...     1
# 3     {"usd":1410403.56057628,"base":155952,"quote":...     1
# 5       {"usd":15980362,"base":6858.66,"quote":7432377}     1
# 6        {"usd":7037957,"base":7028722,"quote":1579534}     1
# ...                                                 ...   ...
# 5258     {"usd":461022,"base":29180285,"quote":7997.94}     1
# 5259  {"usd":526986.0214139478,"base":3112908,"quote...     1
# 5262        {"usd":129404,"base":1935.23,"quote":17.73}     1
# 5264         {"usd":67142,"base":16992072,"quote":2914}     1
# 5266   {"usd":149929,"base":1197219706674,"quote":6419}     1
#
# [2671 rows x 12 columns]

# %%
df.to_csv('./Final.csv')

# %%
df
# Out:
#       Unnamed: 0  Unnamed: 1  index    chainId        dexId baseToken  \
# 0              0           0      0        bsc  pancakeswap      WBNB
# 2              3           3      3        bsc  pancakeswap      FITM
# 3              4           4      4       heco         mdex       WHT
# 5              6           6      6   arbitrum      uniswap      WETH
# 6              7           7      7    polygon      uniswap    WMATIC
# ...          ...         ...    ...        ...          ...       ...
# 5258        6861       32706  33237    polygon      uniswap       XMT
# 5259        6865       32759  33292   arbitrum      camelot      OATH
# 5262        6871       32792  33325   optimism      uniswap      AAVE
# 5264        6877       32822  33357  avalanche    traderjoe      SNCT
# 5266        6880       32839  33374  avalanche    traderjoe     SMRTr
#
#                                 baseTokenAddress quoteToken  \
# 0     0xbb4CdB9CBd36B01bD1cBaEBF2De08d9173bc095c       USDT
# 2     0x41D52514F6eA0c90993AD36152072a144C12bDc7       WBNB
# 3     0x5545153CCFcA01fbd7Dd11C0b23ba694D9509A6F       USDT
# 5     0x82aF49447D8a07e3bd95BD0d56f35241523fBab1       USDC
# 6     0x0d500B1d8E8eF31E21C99d1Db9A6444d3ADf1270       USDC
# ...                                          ...        ...
# 5258  0xadBe0eac80F955363f4Ff47B0f70189093908c04       USDC
# 5259  0xa1150db5105987CEC5Fd092273d1e3cbb22b378b       WETH
# 5262  0x76FB31fb4af56892A25e32cFC43De717950c9278        ETH
# 5264  0x2905d6D6957983d9ED73BC019fF2782c39dd7a49      WAVAX
# 5266  0x6D923f688C7FF287dc3A5943CAeefc994F97b290      WAVAX
#
#                                quoteTokenAddress  \
# 0     0x55d398326f99059fF775485246999027B3197955
# 2     0xbb4CdB9CBd36B01bD1cBaEBF2De08d9173bc095c
# 3     0xa71EdC38d189767582C38A3145b5873052c3e47a
# 5     0xFF970A61A04b1cA14834A43f5dE4533eBDDB5CC8
# 6     0x2791Bca1f2de4661ED88A30C99A7a9449Aa84174
# ...                                          ...
# 5258  0x2791Bca1f2de4661ED88A30C99A7a9449Aa84174
# 5259  0x82aF49447D8a07e3bd95BD0d56f35241523fBab1
# 5262  0x4200000000000000000000000000000000000006
# 5264  0xB31f66AA3C1e785363F0875A1B74E27b85FD66c7
# 5266  0xB31f66AA3C1e785363F0875A1B74E27b85FD66c7
#
#                                      pairAddress  \
# 0     0x16b9a82891338f9bA80E2D6970FddA79D1eb0daE
# 2     0xdD123e5749BB13012aF48b4BcF891146c4f84c45
# 3     0x499B6E03749B4bAF95F9E70EeD5355b138EA6C31
# 5     0xC31E54c7a869B9FcBEcc14363CF510d1c41fa443
# 6     0xA374094527e1673A86dE625aa59517c5dE346d32
# ...                                          ...
# 5258  0xf7aBB7dee889dA4300a82C26f8c0c725c64Bd493
# 5259  0x7fFAf4698635a7679CE508160f2156B8739f37fE
# 5262  0x790fde1FD6d2568050061a88c375d5c2E06b140B
# 5264  0xd81425a1E9A09015B965243F803EF30b6AA605C3
# 5266  0x7B7617c7B2236D7871741783caE8BCc222C2e05D
#
#                                               liquidity  TRUE
# 0     {"usd":121690188.89270122,"base":237541,"quote...     1
# 2     {"usd":132301.72410937824,"base":25907532,"quo...     1
# 3     {"usd":1410403.56057628,"base":155952,"quote":...     1
# 5       {"usd":15980362,"base":6858.66,"quote":7432377}     1
# 6        {"usd":7037957,"base":7028722,"quote":1579534}     1
# ...                                                 ...   ...
# 5258     {"usd":461022,"base":29180285,"quote":7997.94}     1
# 5259  {"usd":526986.0214139478,"base":3112908,"quote...     1
# 5262        {"usd":129404,"base":1935.23,"quote":17.73}     1
# 5264         {"usd":67142,"base":16992072,"quote":2914}     1
# 5266   {"usd":149929,"base":1197219706674,"quote":6419}     1
#
# [2671 rows x 12 columns]

# %%
print(df['baseToken'].value_counts())
# Out:
# WETH           63
# USDC           55
# ETH            45
# WBTC           43
# USDT           42
#                ..
# HTDAO           1
# PITI            1
# AmazingTeam     1
# VGO             1
# SMRTr           1
# Name: baseToken, Length: 1615, dtype: int64

# %%
df['baseToken'].value_counts()

# %%
take = ["WETH","USDC","ETH","WBTC","USDT",]
take_df = df[df['baseToken'] in take]
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /var/folders/l2/_76930j17479_hbmbm2vv0c00000gn/T/ipykernel_44673/2385431918.py in <module>
#       1 take = ["WETH","USDC","ETH","WBTC","USDT",]
# ----> 2 take_df = df[df['baseToken'] in take]
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/generic.py in __nonzero__(self)
#    1525     @final
#    1526     def __nonzero__(self):
# -> 1527         raise ValueError(
#    1528             f"The truth value of a {type(self).__name__} is ambiguous. "
#    1529             "Use a.empty, a.bool(), a.item(), a.any() or a.all()."
#
# ValueError: The truth value of a Series is ambiguous. Use a.empty, a.bool(), a.item(), a.any() or a.all().
