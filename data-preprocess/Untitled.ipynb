# %%
import pandas as pd
import numpy as np
import requests
import json
import csv
import ccxt
import json

# %%
fb_price = pd.read_csv('./Final_by_filter.csv')

fb_price=fb_price[abs(fb_price['priceNative']-fb_price['ccxt'])/fb_price['priceNative'] < 0.2]

# %%
fb_price.to_csv('./Final_by_filter.csv')

# %%
fb_price.drop(['Unnamed: 0','Unnamed: 0.1','Unnamed: 0.2','Unnamed: 0.3'],axis ='columns',inplace = True)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /var/folders/l2/_76930j17479_hbmbm2vv0c00000gn/T/ipykernel_40882/617541059.py in <module>
# ----> 1 fb_price.drop(['Unnamed: 0','Unnamed: 0.1','Unnamed: 0.2','Unnamed: 0.3'],axis ='columns',inplace = True)
#       2 fb_price.reset_index(drop=True)
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4955                 weight  1.0     0.8
#    4956         """
# -> 4957         return super().drop(
#    4958             labels=labels,
#    4959             axis=axis,
#
# ...

# %%
fb_price.reset_index(drop=True)
# Out:
#       chainId                                       dexId baseToken  \
# 0         bsc                                 pancakeswap      WBNB
# 1    arbitrum                                     uniswap      WETH
# 2     polygon                                     uniswap    WMATIC
# 3     osmosis                                     osmosis      ATOM
# 4    ethereum                                     uniswap      WETH
# ..        ...                                         ...       ...
# 287       bsc                                 pancakeswap      BSCX
# 288       oec                                  cherryswap      BUSD
# 289       bsc                                  knightswap      WBNB
# 290       bsc                                 pancakeswap      DATA
# 291       bsc  0xa82f327BBbF0667356D2935C6532d164b06cEced      WBNB
#
#                                       baseTokenAddress quoteToken  \
# 0           0xbb4CdB9CBd36B01bD1cBaEBF2De08d9173bc095c       USDT
# ...

# %%
fb_price.to_csv('./Final_by_filter.csv')

# %%
fb_price['baseToken'].value_counts().to_csv('./frequency')

# %%
take = ["WETH","WBNB","WMATIC","WBTC","WFTM","ETH","BUSD"]
take_df = df[df['baseToken'].isin(take)]
take_df = take_df.reset_index(drop=True)
take_df
